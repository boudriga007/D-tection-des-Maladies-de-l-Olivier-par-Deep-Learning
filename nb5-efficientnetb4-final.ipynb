# %% [markdown]
# # 🫒 Détection des Maladies de l'Olivier — Deep Learning
#
# ---
#
# | Informations | Détails |
# |---|---|
# | **Encadrant** | M. Abdallah Khemais |
# | **Notebook** | 5 / 6 — EfficientNetB4 (Modèle Final) |
# | **Objectif** | Entraîner le meilleur modèle du projet |
#
# ---
#
# ## 🎯 Objectif
#
# 1. ✅ Construire et entraîner **EfficientNetB4** (modèle final)
# 2. ✅ Fine-tuning progressif en 2 phases
# 3. ✅ Learning Rate Scheduler (cosine decay)
# 4. ✅ Courbes d'apprentissage + Matrice de confusion
# 5. ✅ **Grad-CAM** : visualiser ce que le modèle regarde
# 6. ✅ Export **TFLite** pour déploiement mobile
# 7. ✅ Sauvegarde des résultats pour NB6
#
# ---
#
# ## 🔑 Pourquoi EfficientNet ?
#
# | Modèle | Params | ImageNet Top-1 |
# |---|---|---|
# | VGG16 | 138M | 71.3% |
# | ResNet50 | 25M | 76.0% |
# | **EfficientNetB4** | **19M** | **83.0%** |
#
# > EfficientNet utilise le **compound scaling** : augmenter simultanément profondeur, largeur et résolution de façon optimale.
# > Résultat : **meilleure accuracy avec moins de paramètres** !

# %% [markdown]
# ---
# ## 📦 Cellule 1 — Import & Configuration
#
# > **Explication :** Import des librairies et reconstruction du pipeline.

# %%
# ============================================================
# Cellule 1 — Import & Configuration
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import cv2
import os, json, warnings
from pathlib import Path

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix

warnings.filterwarnings('ignore')
np.random.seed(42)
tf.random.set_seed(42)
plt.rcParams['figure.dpi'] = 120
plt.style.use('seaborn-v0_8-whitegrid')

# Chargement config (priorité NB4 → NB2 → NB1)
CONFIG_PATHS = [
    '/kaggle/input/notebooks/ahmedboudriga/nb4-transfer-learning/config.json',
    '/kaggle/input/notebooks/ahmedboudriga/nb2-preprocessing-augmentation/config.json',
    '/kaggle/input/notebooks/ahmedboudriga/nb1-setup-exploration/config.json',
]

config = None
for path in CONFIG_PATHS:
    if os.path.exists(path):
        with open(path, 'r', encoding='utf-8') as f:
            config = json.load(f)
        print(f'Config chargée depuis : {path}')
        break

if config is None:
    raise FileNotFoundError('Aucun config.json trouvé !')

IMG_SIZE    = config['img_size']
BATCH_SIZE  = config['batch_size']
NUM_CLASSES = config['num_classes']
AUTOTUNE    = tf.data.AUTOTUNE

if 'idx_to_class' in config:
    idx_to_class = {int(k): v for k, v in config['idx_to_class'].items()}
else:
    idx_to_class = {i: cls for i, cls in enumerate(config['classes'])}
    print('⚠️  idx_to_class absent → reconstruit depuis classes[]')

CLASS_NAMES = [idx_to_class[i] for i in range(NUM_CLASSES)]

# Chargement des splits
X_train = np.load('/kaggle/input/notebooks/ahmedboudriga/nb2-preprocessing-augmentation/X_train.npy', allow_pickle=True)
X_val   = np.load('/kaggle/input/notebooks/ahmedboudriga/nb2-preprocessing-augmentation/X_val.npy',   allow_pickle=True)
X_test  = np.load('/kaggle/input/notebooks/ahmedboudriga/nb2-preprocessing-augmentation/X_test.npy',  allow_pickle=True)
y_train = np.load('/kaggle/input/notebooks/ahmedboudriga/nb2-preprocessing-augmentation/y_train.npy')
y_val   = np.load('/kaggle/input/notebooks/ahmedboudriga/nb2-preprocessing-augmentation/y_val.npy')
y_test  = np.load('/kaggle/input/notebooks/ahmedboudriga/nb2-preprocessing-augmentation/y_test.npy')

# ── Correction automatique des chemins périmés ────────────────────────────────
def fix_paths(paths):
    if len(paths) == 0 or os.path.exists(paths[0]):
        return paths

    print(f'⚠️  Chemin périmé : {paths[0]}')

    dataset_root = None
    for root, dirs, files in os.walk('/kaggle/input/'):
        if os.path.basename(paths[0]) in files:
            dataset_root = root
            break

    if dataset_root is None:
        raise FileNotFoundError('Dataset introuvable dans /kaggle/input/ — vérifie que le dataset Zeytin est bien ajouté en input.')

    base_old = str(Path(paths[0]).parent.parent)
    base_new = str(Path(dataset_root).parent)

    fixed = np.array([p.replace(base_old, base_new) for p in paths])
    print(f'  Ancien root : {base_old}')
    print(f'  Nouveau root: {base_new}')

    missing = sum(1 for p in fixed if not os.path.exists(p))
    print(f'  Fichiers manquants après correction : {missing} / {len(fixed)}')
    return fixed

print('\nVérification des chemins...')
X_train = fix_paths(X_train)
X_val   = fix_paths(X_val)
X_test  = fix_paths(X_test)
print('Chemins OK ✅')

# ── Pipeline tf.data ──────────────────────────────────────────────────────────
data_aug = tf.keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.15),
    layers.RandomContrast(0.1),
    layers.RandomTranslation(0.1, 0.1),
], name='data_augmentation')

def load_image(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    return img, label

def augment_image(img, label):
    img = data_aug(img, training=True)
    img = tf.clip_by_value(img, 0.0, 1.0)   # ← fix images noires
    return img, label

def build_dataset(paths, labels, augment=False, shuffle=False):
    ds = tf.data.Dataset.from_tensor_slices((paths.tolist(), labels.tolist()))
    if shuffle:
        ds = ds.shuffle(len(paths), seed=42)
    ds = ds.map(load_image, num_parallel_calls=AUTOTUNE)
    if augment:
        ds = ds.map(augment_image, num_parallel_calls=AUTOTUNE)
    return ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)

train_ds = build_dataset(X_train, y_train, augment=True,  shuffle=True)
val_ds   = build_dataset(X_val,   y_val,   augment=False, shuffle=False)
test_ds  = build_dataset(X_test,  y_test,  augment=False, shuffle=False)

print('\nConfiguration chargée !')
print(f'  Classes     : {CLASS_NAMES}')
print(f'  Train       : {len(X_train):,} images')
print(f'  Validation  : {len(X_val):,} images')
print(f'  Test        : {len(X_test):,} images')
# Out:
# Config chargée depuis : /kaggle/input/notebooks/ahmedboudriga/nb4-transfer-learning/config.json
#
# Vérification des chemins...
# Chemins OK ✅
#
# Configuration chargée !
#   Classes     : ['Kus_Gozu_Mantari', 'Pas_Akari', 'Saglikli']
#   Train       : 686 images
#   Validation  : 147 images
#   Test        : 147 images

# %% [markdown]
# ---
# ## 🏗️ Cellule 2 — Architecture EfficientNetB4
#
# > **Explication :** EfficientNetB4 utilise des blocs **MBConv** (Mobile Inverted Bottleneck)
# > avec le mécanisme **Squeeze-and-Excitation** qui recalibre les features channels.
# > - `include_top=False` → on enlève la tête originale (1000 classes)
# > - On ajoute notre propre tête pour 3 classes
# > - **Phase 1** : base gelée → entraîner seulement la tête
# > - **Phase 2** : dégeler les 50 dernières couches → fine-tuning

# %%
# ============================================================
# Cellule 2 — Architecture EfficientNetB4
# Modèle final du projet avec compound scaling
# ============================================================

def build_efficientnetb4(input_shape=(224, 224, 3), num_classes=3):
    """
    EfficientNetB4 pré-entraîné ImageNet + nouvelle tête 3 classes.
    Compound scaling : meilleure accuracy avec moins de paramètres.
    """
    # Base EfficientNetB4 sans tête de classification
    base_model = EfficientNetB4(
        weights='imagenet',
        include_top=False,
        input_shape=input_shape
    )
    base_model.trainable = False  # Gel initial

    inputs = layers.Input(shape=input_shape, name='input')
    x = base_model(inputs, training=False)

    # Tête de classification adaptée à nos 3 maladies
    x = layers.GlobalAveragePooling2D(name='gap')(x)   # (H,W,C) → (C,)
    x = layers.Dense(512, name='dense1')(x)
    x = layers.BatchNormalization(name='bn1')(x)
    x = layers.Activation('relu', name='relu1')(x)
    x = layers.Dropout(0.4, name='drop1')(x)
    x = layers.Dense(128, name='dense2')(x)
    x = layers.BatchNormalization(name='bn2')(x)
    x = layers.Activation('relu', name='relu2')(x)
    x = layers.Dropout(0.3, name='drop2')(x)
    outputs = layers.Dense(num_classes, activation='softmax', name='output')(x)

    model = models.Model(inputs=inputs, outputs=outputs, name='EfficientNetB4_Final')
    return model, base_model

effnet_model, effnet_base = build_efficientnetb4(
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    num_classes=NUM_CLASSES
)

print('EfficientNetB4 construit !')
print(f'  Couches totales base   : {len(effnet_base.layers)}')
print(f'  Params base (gelés)    : {effnet_base.count_params():,}')
print(f'  Params tête            : {effnet_model.count_params() - effnet_base.count_params():,}')
print(f'  Params totaux          : {effnet_model.count_params():,}')
# Out:
# EfficientNetB4 construit !
#   Couches totales base   : 475
#   Params base (gelés)    : 17,673,823
#   Params tête            : 986,627
#   Params totaux          : 18,660,450

# %% [markdown]
# ---
# ## 🚀 Cellule 3 — Entraînement Phase 1 (Feature Extraction)
#
# > **Explication :** Phase 1 : base gelée, on entraîne uniquement la nouvelle tête.

# %%
# ============================================================
# Cellule 3 — Phase 1 : Feature Extraction EfficientNetB4
# ============================================================

# EfficientNetB4 a son propre preprocessing intégré
# → on lui passe des pixels [0, 255], pas [0, 1]
def load_image_effnet(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32)  # ← PAS de /255.0 pour EfficientNet
    return img, label

def augment_image_effnet(img, label):
    img = data_aug(img, training=True)
    img = tf.clip_by_value(img, 0.0, 255.0)  # clip sur [0, 255]
    return img, label

def build_dataset_effnet(paths, labels, augment=False, shuffle=False):
    ds = tf.data.Dataset.from_tensor_slices((paths.tolist(), labels.tolist()))
    if shuffle:
        ds = ds.shuffle(len(paths), seed=42)
    ds = ds.map(load_image_effnet, num_parallel_calls=AUTOTUNE)
    if augment:
        ds = ds.map(augment_image_effnet, num_parallel_calls=AUTOTUNE)
    return ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)

# Reconstruire les datasets avec le bon preprocessing
train_ds = build_dataset_effnet(X_train, y_train, augment=True,  shuffle=True)
val_ds   = build_dataset_effnet(X_val,   y_val,   augment=False, shuffle=False)
test_ds  = build_dataset_effnet(X_test,  y_test,  augment=False, shuffle=False)

print('✅ Datasets reconstruits avec preprocessing EfficientNet [0, 255]')

effnet_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

print('Phase 1 — Feature Extraction (base gelée)...')
history_eff_p1 = effnet_model.fit(
    train_ds, epochs=10,
    validation_data=val_ds,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=5,
                      restore_best_weights=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                          patience=3, min_lr=1e-6, verbose=1)
    ],
    verbose=1
)

print(f'\nPhase 1 terminée !')
print(f'  Best val_accuracy : {max(history_eff_p1.history["val_accuracy"]):.4f}')
# Out:
# ✅ Datasets reconstruits avec preprocessing EfficientNet [0, 255]
# Phase 1 — Feature Extraction (base gelée)...
# Epoch 1/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.5405 - loss: 1.0549 - val_accuracy: 0.7755 - val_loss: 0.6468 - learning_rate: 0.0010
# Epoch 2/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 322ms/step - accuracy: 0.7886 - loss: 0.5144 - val_accuracy: 0.7823 - val_loss: 0.5255 - learning_rate: 0.0010
# Epoch 3/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 324ms/step - accuracy: 0.8613 - loss: 0.3757 - val_accuracy: 0.7755 - val_loss: 0.5084 - learning_rate: 0.0010
# Epoch 4/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 319ms/step - accuracy: 0.8723 - loss: 0.3271 - val_accuracy: 0.8231 - val_loss: 0.4235 - learning_rate: 0.0010
# Epoch 5/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 319ms/step - accuracy: 0.8982 - loss: 0.2894 - val_accuracy: 0.8299 - val_loss: 0.4072 - learning_rate: 0.0010
# Epoch 6/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 317ms/step - accuracy: 0.8737 - loss: 0.3054 - val_accuracy: 0.8299 - val_loss: 0.3735 - learning_rate: 0.0010
# Epoch 7/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 320ms/step - accuracy: 0.8675 - loss: 0.3238 - val_accuracy: 0.8639 - val_loss: 0.3637 - learning_rate: 0.0010
# Epoch 8/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 316ms/step - accuracy: 0.8785 - loss: 0.2866 - val_accuracy: 0.8912 - val_loss: 0.3250 - learning_rate: 0.0010
# Epoch 9/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 304ms/step - accuracy: 0.8799 - loss: 0.3030 - val_accuracy: 0.8980 - val_loss: 0.3724 - learning_rate: 0.0010
# Epoch 10/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - accuracy: 0.8748 - loss: 0.3190 - val_accuracy: 0.8707 - val_loss: 0.3423 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 8.
#
# Phase 1 terminée !
#   Best val_accuracy : 0.8980

# %% [markdown]
# ---
# ## 🔥 Cellule 4 — Entraînement Phase 2 (Fine-tuning)
#
# > **Explication :** On dégèle les **50 dernières couches** et on utilise un lr très faible.
# > Le **cosine decay** (ReduceLROnPlateau) permet une décroissance douce du learning rate.

# %%
# ============================================================
# Cellule 4 — Phase 2 : Fine-tuning EfficientNetB4
# ============================================================

# Dégeler les 50 dernières couches
effnet_base.trainable = True
for layer in effnet_base.layers[:-50]:
    layer.trainable = False

trainable = sum(1 for l in effnet_model.layers if l.trainable)
print(f'Phase 2 — Fine-tuning (50 dernières couches)')
print(f'  Couches entraînables : {trainable}')

EFFNET_PATH = '/kaggle/working/olive_efficientnetb4_best.keras'

effnet_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

history_eff_p2 = effnet_model.fit(
    train_ds, epochs=30,
    validation_data=val_ds,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=8,
                      restore_best_weights=True, verbose=1),
        ModelCheckpoint(EFFNET_PATH, monitor='val_accuracy',
                        save_best_only=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                          patience=4, min_lr=1e-8, verbose=1)
    ],
    verbose=1
)

eff_loss, eff_acc = effnet_model.evaluate(test_ds, verbose=0)
print(f'\nRésultats EfficientNetB4 sur Test Set :')
print(f'  Test Accuracy : {eff_acc:.4f} ({eff_acc*100:.2f}%)')
print(f'  Test Loss     : {eff_loss:.4f}')
# Out:
# Phase 2 — Fine-tuning (50 dernières couches)
#   Couches entraînables : 12
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8403 - loss: 0.4214
# Epoch 1: val_accuracy improved from -inf to 0.89796, saving model to /kaggle/working/olive_efficientnetb4_best.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 116s 3s/step - accuracy: 0.8412 - loss: 0.4199 - val_accuracy: 0.8980 - val_loss: 0.3157 - learning_rate: 1.0000e-05
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8562 - loss: 0.3871
# Epoch 2: val_accuracy improved from 0.89796 to 0.91837, saving model to /kaggle/working/olive_efficientnetb4_best.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 416ms/step - accuracy: 0.8565 - loss: 0.3864 - val_accuracy: 0.9184 - val_loss: 0.3085 - learning_rate: 1.0000e-05
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.8827 - loss: 0.3346
# Epoch 3: val_accuracy did not improve from 0.91837
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - accuracy: 0.8825 - loss: 0.3353 - val_accuracy: 0.9184 - val_loss: 0.3143 - learning_rate: 1.0000e-05
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.8588 - loss: 0.3610
# Epoch 4: val_accuracy did not improve from 0.91837
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - accuracy: 0.8594 - loss: 0.3594 - val_accuracy: 0.9116 - val_loss: 0.3195 - learning_rate: 1.0000e-05
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8897 - loss: 0.3203
# Epoch 5: val_accuracy did not improve from 0.91837
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 335ms/step - accuracy: 0.8892 - loss: 0.3206 - val_accuracy: 0.9048 - val_loss: 0.3244 - learning_rate: 1.0000e-05
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.8736 - loss: 0.3708
# Epoch 6: val_accuracy did not improve from 0.91837
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - accuracy: 0.8736 - loss: 0.3696 - val_accuracy: 0.9116 - val_loss: 0.3306 - learning_rate: 1.0000e-05
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9057 - loss: 0.2931
# Epoch 7: val_accuracy did not improve from 0.91837
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 326ms/step - accuracy: 0.9058 - loss: 0.2922 - val_accuracy: 0.8980 - val_loss: 0.3361 - learning_rate: 5.0000e-06
# Epoch 8/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8602 - loss: 0.3213
# Epoch 8: val_accuracy did not improve from 0.91837
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 322ms/step - accuracy: 0.8608 - loss: 0.3201 - val_accuracy: 0.8980 - val_loss: 0.3392 - learning_rate: 5.0000e-06
# Epoch 9/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.8624 - loss: 0.3398
# Epoch 9: val_accuracy did not improve from 0.91837
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 322ms/step - accuracy: 0.8631 - loss: 0.3385 - val_accuracy: 0.8912 - val_loss: 0.3431 - learning_rate: 5.0000e-06
# Epoch 10/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9100 - loss: 0.2376
# Epoch 10: val_accuracy did not improve from 0.91837
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 321ms/step - accuracy: 0.9095 - loss: 0.2388 - val_accuracy: 0.8844 - val_loss: 0.3425 - learning_rate: 5.0000e-06
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 2.
#
# Résultats EfficientNetB4 sur Test Set :
#   Test Accuracy : 0.9184 (91.84%)
#   Test Loss     : 0.2184

# %% [markdown]
# ---
# ## 📈 Cellule 5 — Courbes d'Apprentissage
#
# > **Explication :** On trace les courbes des deux phases combinées pour voir l'évolution complète.

# %%
# ============================================================
# Cellule 5 — Courbes d'Apprentissage EfficientNetB4
# Phase 1 + Phase 2 combinées
# ============================================================

# Combinaison des deux historiques
acc_p1     = history_eff_p1.history['accuracy']
val_acc_p1 = history_eff_p1.history['val_accuracy']
loss_p1    = history_eff_p1.history['loss']
val_loss_p1= history_eff_p1.history['val_loss']

acc_p2     = history_eff_p2.history['accuracy']
val_acc_p2 = history_eff_p2.history['val_accuracy']
loss_p2    = history_eff_p2.history['loss']
val_loss_p2= history_eff_p2.history['val_loss']

all_acc     = acc_p1  + acc_p2
all_val_acc = val_acc_p1 + val_acc_p2
all_loss    = loss_p1 + loss_p2
all_val_loss= val_loss_p1 + val_loss_p2
ep_split    = len(acc_p1)
ep_total    = len(all_acc)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Courbes d\'apprentissage — EfficientNetB4 (Phase 1 + Phase 2)',
             fontsize=14, fontweight='bold')

for ax, (train_v, val_v, title) in zip(axes, [
    (all_loss,    all_val_loss, 'Loss'),
    (all_acc,     all_val_acc,  'Accuracy')
]):
    ep = range(1, ep_total + 1)
    ax.plot(ep, train_v, label='Train', color='#2d7a2d', lw=2)
    ax.plot(ep, val_v,   label='Val',   color='#c0392b', lw=2, ls='--')
    ax.axvline(ep_split, color='orange', ls=':', lw=2, label=f'Phase 2 début (ep {ep_split})')
    ax.set_title(f'EfficientNetB4 — {title}', fontweight='bold')
    ax.set_xlabel('Epoch')
    ax.set_ylabel(title)
    if title == 'Accuracy':
        ax.set_ylim(0, 1.05)
    ax.legend()
    ax.spines[['top','right']].set_visible(False)

plt.tight_layout()
plt.savefig('/kaggle/working/12_learning_curves_efficientnet.png', dpi=150, bbox_inches='tight')
plt.show()
print('Figure sauvegardée --> /kaggle/working/12_learning_curves_efficientnet.png')
# Out:
# Figure sauvegardée --> /kaggle/working/12_learning_curves_efficientnet.png

# %% [markdown]
# ---
# ## 🔲 Cellule 6 — Matrice de Confusion + Rapport
#
# > **Explication :** Évaluation complète du modèle final sur le test set.

# %%
# ============================================================
# Cellule 6 — Matrice de Confusion + Rapport de Classification
# ============================================================

y_pred_proba = effnet_model.predict(test_ds, verbose=0)
y_pred       = np.argmax(y_pred_proba, axis=1)

# Rapport complet
print('Rapport de classification — EfficientNetB4 :')
print(classification_report(y_test, y_pred, target_names=CLASS_NAMES, digits=4))

# Matrice de confusion
cm      = confusion_matrix(y_test, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
fig.suptitle('Matrice de Confusion — EfficientNetB4', fontsize=14, fontweight='bold')

sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
            ax=axes[0], linewidths=0.5)
axes[0].set_title('Valeurs absolues', fontweight='bold')
axes[0].set_xlabel('Prédiction')
axes[0].set_ylabel('Vraie classe')
axes[0].tick_params(axis='x', rotation=15)

sns.heatmap(cm_norm, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
            ax=axes[1], linewidths=0.5)
axes[1].set_title('Normalisée (%)', fontweight='bold')
axes[1].set_xlabel('Prédiction')
axes[1].set_ylabel('Vraie classe')
axes[1].tick_params(axis='x', rotation=15)

plt.tight_layout()
plt.savefig('/kaggle/working/13_confusion_efficientnet.png', dpi=150, bbox_inches='tight')
plt.show()
print('Figure sauvegardée --> /kaggle/working/13_confusion_efficientnet.png')
# Out:
# Rapport de classification — EfficientNetB4 :
#                   precision    recall  f1-score   support
#
# Kus_Gozu_Mantari     0.9412    0.9275    0.9343        69
#        Pas_Akari     0.8889    0.9091    0.8989        44
#         Saglikli     0.9118    0.9118    0.9118        34
#
#         accuracy                         0.9184       147
#        macro avg     0.9139    0.9161    0.9150       147
#     weighted avg     0.9187    0.9184    0.9185       147
# Figure sauvegardée --> /kaggle/working/13_confusion_efficientnet.png

# %% [markdown]
# ---
# ## 🔥 Cellule 7 — Grad-CAM (Visualisation des Zones Actives)
#
# > **Explication :** **Grad-CAM** (Gradient-weighted Class Activation Mapping) permet de visualiser
# > **quelles zones de l'image** ont influencé la décision du modèle.
# > - Calcule le gradient de la classe prédite par rapport aux feature maps de la dernière couche conv
# > - Produit une **heatmap** superposée sur l'image originale
# > - Rouge = zones très importantes pour la décision
# > - Bleu = zones peu importantes
# >
# > **Importance pour le prof :** C'est l'**interprétabilité** du modèle — on justifie pourquoi le modèle dit "maladie" !

# %%
# ============================================================
# Cellule 7 — Grad-CAM EfficientNetB4
# ============================================================

import matplotlib.cm as cm

# Trouver la dernière couche conv dans la base EfficientNetB4
base_model = effnet_model.get_layer('efficientnetb4')
last_conv_layer = [l.name for l in base_model.layers
                   if isinstance(l, tf.keras.layers.Conv2D)][-1]
print(f'Dernière couche conv : {last_conv_layer}')

def make_gradcam_heatmap(img_array, last_conv_layer_name):
    """
    Grad-CAM en construisant le grad_model depuis la base directement.
    img_array : shape (1, H, W, C) en float32 [0, 255]
    """
    # Construire un modèle intermédiaire sur la base seule
    base     = effnet_model.get_layer('efficientnetb4')
    conv_out = base.get_layer(last_conv_layer_name).output

    # Modèle 1 : input → features conv
    feat_model = tf.keras.Model(
        inputs=base.input,
        outputs=conv_out
    )

    # Modèle 2 : features conv → sortie finale (GAP + Dense)
    gap_input = tf.keras.Input(shape=conv_out.shape[1:])
    x = effnet_model.get_layer('gap')(gap_input)
    x = effnet_model.get_layer('dense1')(x)
    x = effnet_model.get_layer('bn1')(x)
    x = effnet_model.get_layer('relu1')(x)
    x = effnet_model.get_layer('drop1')(x)
    x = effnet_model.get_layer('dense2')(x)
    x = effnet_model.get_layer('bn2')(x)
    x = effnet_model.get_layer('relu2')(x)
    x = effnet_model.get_layer('drop2')(x)
    out = effnet_model.get_layer('output')(x)
    head_model = tf.keras.Model(inputs=gap_input, outputs=out)

    with tf.GradientTape() as tape:
        inputs   = tf.cast(img_array, tf.float32)
        conv_outputs = feat_model(inputs)
        tape.watch(conv_outputs)
        predictions  = head_model(conv_outputs)
        pred_index   = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]

    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads  = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs  = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy(), predictions.numpy()

# ── Visualisation ─────────────────────────────────────────────────────────────
n_rows = NUM_CLASSES * 2
fig, axes = plt.subplots(n_rows, 3, figsize=(12, n_rows * 4))
fig.suptitle("Grad-CAM — Zones d'attention du modèle EfficientNetB4",
             fontsize=14, fontweight='bold')

for ax, title in zip(axes[0], ['Image Originale', 'Heatmap Grad-CAM', 'Superposition']):
    ax.set_title(title, fontsize=11, fontweight='bold')

row = 0
for cls_idx in range(NUM_CLASSES):
    cls_paths = X_test[y_test == cls_idx][:2]
    for img_path in cls_paths:
        try:
            # Charger en [0, 255] pour EfficientNet
            img_orig = cv2.imread(img_path)
            img_orig = cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)
            img_orig = cv2.resize(img_orig, (IMG_SIZE, IMG_SIZE))
            img_input = np.expand_dims(img_orig.astype(np.float32), axis=0)

            heatmap, preds = make_gradcam_heatmap(img_input, last_conv_layer)

            pred_idx = np.argmax(preds[0])
            conf     = preds[0][pred_idx]
            correct  = '✅ Correct' if pred_idx == cls_idx else '❌ Incorrect'
            color    = 'green' if pred_idx == cls_idx else 'red'

            heat_r  = cv2.resize(heatmap, (IMG_SIZE, IMG_SIZE))
            heat_c  = cv2.applyColorMap(np.uint8(255 * heat_r), cv2.COLORMAP_JET)
            heat_c  = cv2.cvtColor(heat_c, cv2.COLOR_BGR2RGB)
            overlay = cv2.addWeighted(img_orig, 0.6, heat_c, 0.4, 0)

            axes[row, 0].imshow(img_orig)
            axes[row, 0].set_ylabel(f'{correct}\nVraie: {CLASS_NAMES[cls_idx]}',
                                     fontsize=9, color=color)
            axes[row, 0].axis('off')
            axes[row, 1].imshow(heat_r, cmap='jet')
            axes[row, 1].set_title(f'Prédit: {CLASS_NAMES[pred_idx]} ({conf:.1%})',
                                    fontsize=8, color=color)
            axes[row, 1].axis('off')
            axes[row, 2].imshow(overlay)
            axes[row, 2].axis('off')

        except Exception as e:
            print(f'Erreur Grad-CAM row {row}: {e}')
            for ax in axes[row]:
                ax.axis('off')
        row += 1

plt.tight_layout()
plt.savefig('/kaggle/working/14_gradcam_efficientnet.png', dpi=150, bbox_inches='tight')
plt.show()
print('Figure Grad-CAM sauvegardée --> /kaggle/working/14_gradcam_efficientnet.png')
# Out:
# Dernière couche conv : top_conv
# Figure Grad-CAM sauvegardée --> /kaggle/working/14_gradcam_efficientnet.png

# %% [markdown]
# ---
# ## 📱 Cellule 8 — Export TFLite (déploiement mobile)
#
# > **Explication :** On convertit le modèle en format **TFLite** pour le déployer sur Android.
# > - TFLite est optimisé pour les appareils mobiles (moins de mémoire, plus rapide)
# > - La quantification (INT8) réduit la taille du modèle de 75%
# > - Ce fichier `.tflite` sera utilisé dans l'application Streamlit (Bonus)

# %%
# ============================================================
# Cellule 8 — Export TFLite pour Déploiement Mobile
# ============================================================

EFFNET_PATH   = '/kaggle/working/olive_efficientnetb4_best.keras'
SAVED_MODEL_PATH = '/kaggle/working/efficientnetb4_savedmodel'
TFLITE_PATH   = '/kaggle/working/olive_model.tflite'

# Sauvegarde format .keras (Keras 3)
effnet_model.save(EFFNET_PATH)
print(f'Modèle .keras sauvegardé → {EFFNET_PATH}')

# Export SavedModel pour TFLite (utiliser .export() dans Keras 3)
effnet_model.export(SAVED_MODEL_PATH)
print(f'Modèle SavedModel exporté → {SAVED_MODEL_PATH}')

# Conversion TFLite
converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL_PATH)
converter.optimizations = [tf.lite.Optimize.DEFAULT]   # quantization int8
tflite_model = converter.convert()

with open(TFLITE_PATH, 'wb') as f:
    f.write(tflite_model)

tflite_size_mb = os.path.getsize(TFLITE_PATH) / (1024 * 1024)
keras_size_mb  = os.path.getsize(EFFNET_PATH)  / (1024 * 1024)

print(f'\nExport TFLite terminé !')
print(f'  Modèle .keras  : {keras_size_mb:.1f} MB')
print(f'  Modèle .tflite : {tflite_size_mb:.1f} MB')

# Test inférence TFLite
interpreter = tf.lite.Interpreter(model_path=TFLITE_PATH)
interpreter.allocate_tensors()
input_details  = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print(f'\nTest inférence TFLite :')
print(f'  Input shape  : {input_details[0]["shape"]}')
print(f'  Output shape : {output_details[0]["shape"]}')
print(f'  Classes      : {CLASS_NAMES}')
print('\n✅ Modèle prêt pour déploiement mobile !')
# Out:
# Modèle .keras sauvegardé → /kaggle/working/olive_efficientnetb4_best.keras
# INFO:tensorflow:Assets written to: /kaggle/working/efficientnetb4_savedmodel/assets
# INFO:tensorflow:Assets written to: /kaggle/working/efficientnetb4_savedmodel/assets
# Saved artifact at '/kaggle/working/efficientnetb4_savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   138541657050384: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   138541657052880: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   138545070275280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138545070275088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138545070276432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138545070275472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138545070275856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138545070276240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686051280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686050512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686052240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686052432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686050704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686052816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686050896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686051088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686052624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686051472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686053392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686052048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686054160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686051856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686053584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686053968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686054544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686055120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686054352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686055504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686051664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686054928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686055312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686053008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686056080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686054736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686056848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686057040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686056464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686055696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686057424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686058000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686056656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686056272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686057808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686058384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686058960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686058192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686059344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686057232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686058768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686059152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686057616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686059920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686058576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138544533437136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686055888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686060112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686060496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686061072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686061648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686060880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686060304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686061456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686062032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686062608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686061840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686062992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686059728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686062416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686062800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686061264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686063568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686062224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686064336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686064528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686063952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686063184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686064912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686065488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686064144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686063376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686064720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686065104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686059536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686065296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540686063760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682477840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682478992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682478608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682478416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682480144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682479376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682481296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682481104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682482256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682481488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682482640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682480528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682482064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682482448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682480912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682483216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682481872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682483984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682484176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682483600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682482832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682484560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682485136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682483792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682483408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682484944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682485520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682486096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682485328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682486480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682484368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682485904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682486288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682484752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682487056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682485712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682487824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682483024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682487248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682487632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682488208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682488784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682488016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682487440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682488592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682489168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682489744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682488976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682490128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682486864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682489552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682489936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682488400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682490704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682489360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682491472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682491664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682491088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682490320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682492048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682492624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682491280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682490896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682492432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682493008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682493584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682492816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682486672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682490512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682492240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682493776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682493200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684985552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682493392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540682491856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684985936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684984784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684985744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684986320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684986896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684985360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684984400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684986704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684987280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684987856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684987088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684988240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684986128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684987664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684988048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684986512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684988816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684987472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684989584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684989776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684989200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684988432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684990160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684990736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684989392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684989008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684990544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684991120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684991696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684990928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684992080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684989968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684991504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684991888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684990352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684992656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684991312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684993424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684988624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684992848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684993232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684993808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684994384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684993616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684993040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684994192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684994768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684995344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684994576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684995728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684992464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684995152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684995536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684994000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684996304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684994960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684997072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684997264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684996688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684995920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684997648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684998224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684996880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684996496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684998032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684998608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684999184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684998416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684999568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684997456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684998992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684999376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540685000144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540685000336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684999952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540685000528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684992272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684999760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683477072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684997840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540684996112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683478416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683477456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683479376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683478608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683478032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683478992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683481104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683481296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683482256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683480912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683480528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683482064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683482640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683483216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683482448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683483600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683481488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683483024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683483408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683481872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683484176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683482832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683484944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683485136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683484560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683483792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683485520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683486096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683484752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683484368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683485904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683486480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683487056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683486288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683487440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683485328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683486864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683487248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683485712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683488016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683486672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683488784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683488976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683488400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683487632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683489360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683489936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683488592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683488208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683489744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683490320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683490896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683490128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683491280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683489168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683490704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683491088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683489552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683491856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683490512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683492624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683487824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683492432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683492240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683478224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683491472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683493008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683492816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683492048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683493200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138540683491664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660520720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660522064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660521872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660521296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660520912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660521104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660522640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660521488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660523408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660523600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660523024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660522256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660523984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660524560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660523216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660522832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660524368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660524944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660525520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660524752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660525904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660523792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660525328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660525712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660524176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660526480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660525136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660527248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660527440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660526864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660526096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660527824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660528400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660527056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660526672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660528208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660528784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660529360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660528592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660529744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660527632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660529168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660529552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660528016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660530320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660528976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660531088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660531280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660530704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660529936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660531664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660532240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660530896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660530512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660532048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660532624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660533200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660532432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660533584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660531472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660533008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660533392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660531856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660534160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660532816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660534928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660535120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660534544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660533776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660535504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660536080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660534736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660535888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660520528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660535312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660535696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660536464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660536656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660534352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660533968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541660536272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659244112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659244304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659243536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659242960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659244688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659243152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659245072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659245648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659242576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659245456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659246032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659246608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659245840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659246992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659244880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659246416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659246800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659245264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659247568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659246224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659248336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659243920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659247760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659248144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659248720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659249296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659248528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659247952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659249104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659249680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659250256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659249488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659250640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659247376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659250448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659248912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659251216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659249872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659251984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659252176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659251600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659250832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659252560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659253136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659251792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659251408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659252944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659253520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659254096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659253328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659254480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659252368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659253904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659254288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659252752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659255056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659253712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659255824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659256016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659255440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659254672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659256400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659256976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659255632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659255248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659256784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659257360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659257936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659257168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659256208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659254864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659256592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659247184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659257744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659258320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659257552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659258128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541659258704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658080272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658079888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658081040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658081232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658079504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658079696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658080080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658081616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658082192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658081424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658082576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658080656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658082000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658082384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658080848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658083152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658081808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658083920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658084112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658083536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658082768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658084496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658085072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658083728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658083344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658084880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658085456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658086032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658085264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658086416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658084304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658085840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658086224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658084688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658086992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658085648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658087760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658087952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658087376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658086608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658088336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658088912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658087568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658087184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658088720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658089296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658089872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658089104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658090256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658088144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658089680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658090064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658088528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658090832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658089488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658091600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658091792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658091216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658090448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658092176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658092752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658091408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658091024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658092560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658093136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658093712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658092944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658094096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658091984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658093520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658093904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658092368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658094672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658093328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658095440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658095056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658094480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658094864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658079312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658094288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541658095248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657048080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657047696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657048848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657049040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657047312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657049424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657048272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657047888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657049232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657047120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657050000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657048656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657050768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657048464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138547942448336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541890371408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138547942448720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138545070269328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138545070268944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657049616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657051152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138547942448912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657050576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657051344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657052112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657051920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657047504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657051536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657050192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657052688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657049808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657053456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657053648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657053072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657052304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657054032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657054608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138545070273552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138545070276048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657053840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657055568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657055376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657052496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657055952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657055760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657054800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657056912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657056720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657056144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657057296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541657057104: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modèle SavedModel exporté → /kaggle/working/efficientnetb4_savedmodel
# W0000 00:00:1778719146.562849      57 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1778719146.562888      57 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Export TFLite terminé !
#   Modèle .keras  : 132.8 MB
#   Modèle .tflite : 19.1 MB
#
# Test inférence TFLite :
#   Input shape  : [  1 224 224   3]
#   Output shape : [1 3]
#   Classes      : ['Kus_Gozu_Mantari', 'Pas_Akari', 'Saglikli']
#
# ✅ Modèle prêt pour déploiement mobile !

# %% [markdown]
# ---
# ## 💾 Cellule 9 — Sauvegarde des Résultats Finaux
#
# > **Explication :** On sauvegarde tous les résultats pour le notebook final NB6.

# %%
# ============================================================
# Cellule 9 — Sauvegarde des Résultats Finaux
# ============================================================

config['results'] = config.get('results', {})
config['results']['EfficientNetB4'] = {
    'test_accuracy'   : round(float(eff_acc), 4),
    'test_loss'       : round(float(eff_loss), 4),
    'total_params'    : effnet_model.count_params(),
    'epochs_p1'       : len(history_eff_p1.history['loss']),
    'epochs_p2'       : len(history_eff_p2.history['loss']),
    'best_val_acc'    : round(float(max(history_eff_p2.history['val_accuracy'])), 4),
    'model_path'      : EFFNET_PATH,
    'tflite_path'     : TFLITE_PATH,
}
config['final_model'] = 'EfficientNetB4'

with open('/kaggle/working/config.json', 'w', encoding='utf-8') as f:
    json.dump(config, f, indent=2, ensure_ascii=False)

# Historique complet
history_df = pd.DataFrame({
    'accuracy'    : all_acc,
    'val_accuracy': all_val_acc,
    'loss'        : all_loss,
    'val_loss'    : all_val_loss,
})
history_df.to_csv('/kaggle/working/history_efficientnetb4.csv', index=False)

# Résumé final
print('=' * 60)
print('Résultats Finaux — Comparaison Complète')
print('=' * 60)
for model_name, res in config.get('results', {}).items():
    acc = res.get('test_accuracy', 0)
    params = res.get('total_params', 0)
    print(f'  {model_name:<20} : {acc*100:.2f}%   ({params:,} params)')
print('=' * 60)
print('\nTous les résultats sauvegardés !')
print('🚀 Prochaine étape : NB6 — Notebook Final Comparaison Complète')
# Out:
# ============================================================
# Résultats Finaux — Comparaison Complète
# ============================================================
#   ResNet50             : 57.14%   (24,705,411 params)
#   VGG16                : 91.84%   (15,045,443 params)
#   EfficientNetB4       : 91.84%   (18,660,450 params)
# ============================================================
#
# Tous les résultats sauvegardés !
# 🚀 Prochaine étape : NB6 — Notebook Final Comparaison Complète

# %% [markdown]
# ---
# ## ✅ Récapitulatif du Notebook 5
#
# | Cellule | Tâche | Statut |
# |---------|-------|--------|
# | 1 | Import & reconstruction pipeline | ✅ |
# | 2 | Architecture EfficientNetB4 | ✅ |
# | 3 | Phase 1 — Feature Extraction | ✅ |
# | 4 | Phase 2 — Fine-tuning (50 dernières couches) | ✅ |
# | 5 | Courbes d'apprentissage (Phase 1 + Phase 2) | ✅ |
# | 6 | Matrice de confusion + Rapport de classification | ✅ |
# | 7 | Grad-CAM — Interprétabilité du modèle | ✅ |
# | 8 | Export TFLite pour déploiement mobile | ✅ |
# | 9 | Sauvegarde résultats finaux | ✅ |
#
# ---
# ### 🚀 Prochain Notebook — NB6 : Notebook Final (Comparaison complète)
